# %% [markdown]
# # ATM card machine

# %%
user_data={"Laukik":{"name":"Laukik",
                        "pin":4751,
                        "balance":20000,
                        "mobile_no":4561237890,
                        "gmail":"laukik@gmail.com",
                        "credit_card":"no"
    
                        },
               "Ravindra":{"name":"Ravindra",
                        "pin":4524,
                        "balance":45000,
                        "mobile_no":4815263719,
                        "gmail":"ravindra@gmail.com",
                        "credit_card":"no"
    
                        },
               "Chetana":{"name":"Chetana",
                        "pin":1548,
                        "balance":40000,
                        "mobile_no":7531598526,
                        "gmail":"chetana@gmail.com",
                        "credit_card":"yes"
    
                        },
                 "Suraj":{"name":"Suraj",
                        "pin":8754,
                        "balance":80000,
                        "mobile_no":1478523690,
                        "gmail":"suraj@gmail.com",
                        "credit_card":"yes"
    
                        },
            "Sarthak":{"name":"Sarthak",
                        "pin":9634,
                        "balance":40000,
                        "mobile_no":1823965404,
                        "gmail":"sarthak@gmail.com",
                        "credit_card":"no"
                      },
           "Shubham":{"name":"Shubham",
                        "pin":4751,
                        "balance":60000,
                        "mobile_no":1830257964,
                        "gmail":"shubham@gmail.com",
                        "credit_card":"no"
                     }
}
user_data["Shubham"]["mobile_no"]
# Out:
# 1830257964

# %%
user_data={"Laukik":{"name":"Laukik",
                        "pin":4751,
                        "balance":20000,
                        "mobile_no":4561237890,
                        "gmail":"laukik@gmail.com",
                        "credit_card":"no"
    
                        },
               "Ravindra":{"name":"Ravindra",
                        "pin":4524,
                        "balance":45000,
                        "mobile_no":4815263719,
                        "gmail":"ravindra@gmail.com",
                        "credit_card":"no"
    
                        },
               "Chetana":{"name":"Chetana",
                        "pin":1548,
                        "balance":40000,
                        "mobile_no":7531598526,
                        "gmail":"chetana@gmail.com",
                        "credit_card":"yes"
    
                        },
                 "Suraj":{"name":"Suraj",
                        "pin":8754,
                        "balance":80000,
                        "mobile_no":1478523690,
                        "gmail":"suraj@gmail.com",
                        "credit_card":"yes"
    
                        },
            "Sarthak":{"name":"Sarthak",
                        "pin":9634,
                        "balance":40000,
                        "mobile_no":1823965404,
                        "gmail":"sarthak@gmail.com",
                        "credit_card":"no"
                      },
           "Shubham":{"name":"Shubham",
                        "pin":4751,
                        "balance":60000,
                        "mobile_no":1830257964,
                        "gmail":"shubham@gmail.com",
                        "credit_card":"no"
                     }
}

class ATM:
    bank_name="SBI"
    
    def __init__(self,name,balance):
        self.name=name
        self.balance=balance
        
        
    def deposit(self,amount):
        self.balance=self.balance+amount
        print(f"After the successfull deposit your balance is::::{self.balance}")
       
    
    def withdraw(self,amount):
        if amount > self.balance:
            print(f"Insufficient funds, cannot withdraw as the amount you wish to withraw::::{amount} \
            is greater than your balance::::{self.balance}")
        else:
            self.balance=self.balance-amount
            print(f"you can collect your amount:::: {amount} and your balance is:::{self.balance}")
            
        
    def balance_check(self):
        print("Your balance is", self.balance)
        
    def transfer_amount(self,transfer_bank_name,amount):
        user_data.update({transfer_bank_name:amount})
        self.balance=self.balance-amount
        print(f"the {amount} is successfully transfered into the {transfer_bank_name}. Your balance now is:{self.balance}")
    
    def add_benficiary(self,ben_name):
        user_data.update({"beneficiary":ben_name})
        print("***beneficiary is added into your account successfully***")
    
    def update_mobile(self,name,mobile_no):
        """
        what:
        input
        return
        """
        
        if name==user_data[name]["name"] and mobile_no==user_data[name]["mobile_no"]:
            print("***Details matched. do the next step***")
            update_mobile_no=int(input("enter the new number: "))
            user_data.update({"mobile_no":update_mobile_no})
            print("***Mobile number is updated into your account successfully***")
                    
        else:
            print("Invalid details")
       
    
    def update_mail(self,name,gmail):
        if name==user_data[name]["name"] and gmail==user_data[name]["gmail"]:
            print("***Details matched. do the next step***")
            update_email_id=eval(input("enter new email id: "))
            user_data.update({"gmail":gmail})
            print("***email id is updated into your account successfully***")
                    
        else:
            print("Invalid Details")
        
        
    def credit_card(self,cc):
        ""
        if cc=="Y" or y:
            user_data.update({"credit_card":cc})
            print("***Congratulations on getting a credit card.\ncredit card details updated into your account successfully***")
        else:
            print("No problem Sir/Mam. Reach out to your nearest bank branch in future need")
        
        
name=input("enter your name: ").title()
balance=user_data[name]["balance"]
user1=ATM(name,balance)
print(f"****Hi {name}, welcome to {user1.bank_name}****")
pin=int(input("enter your 4 digit pin: "))
if pin==user_data[name]["pin"]:
    print(f"***Welcome to {user1.bank_name} bank ATM machine ")
    while True:
           
        options=input("Enter the options:::\n D==Depoist \n W=Withdrawal \n B==Balance Check \n T==Transfer amount \n UM==update mobile \n UG==update gmail \n AB==add beneficiary \n C==apply credit card \n E==Exit\n") 
        
        if options=="D" or options=="d":
            amount=float(input("Enter the amount you wish to depoist"))
            user1.deposit(amount)
        
        elif options=="w" or options=="W":
            amount=float(input("Enter the amount you wish to withdraw"))
            user1.withdraw(amount) 
            
        elif options=="B" or options=="b":            
            user1.balance_check()
            
        elif options=="t" or options=="T":
            transfer_bank_name=input("enter the bank name where you want to transfer amount")
            amount=eval(input("enter the amount you want to transfer: "))
            user1.transfer_amount(transfer_bank_name,amount)
            
        elif options=="UM" or options=="um":
            print("**To proceed further, we need to verify your details first**")
            name1=input("enter your name: ").title()
            mobile1=int(input("enter your mobile no:"))
            user1.update_mobile(name1,mobile1)
            
                    
        elif options=="UG" or options=="ug":
            print("**To proceed further, we need to verify your details first**")
            name=input("enter your name: ").title()
            gmail=input("enter your mail_id: ")
            user1.update_mail(name,gmail)
            
                    
        elif options=="AB" or options=="ab":
            ben_name=input("enter the beneficiary name: ")
            user1.add_benficiary(ben_name)
        
        elif options=="C" or options=="c":
            cc=input("Do you want credit card? if yes type 'Y' if no then type 'N' : ")
            user1.credit_card(cc)
            
        elif options=="e" or options=="E":
            print("Thanks for banking with us, have a good day")
            break  
        
        else:
            print("Invalid Input")
        
        
else:
    print("wrong pin,enter again")
# Out:
# enter your name: Laukik
# ****Hi Laukik, welcome to SBI****
# enter your 4 digit pin: 4751
# ***Welcome to SBI bank ATM machine
# Enter the options:::
#  D==Depoist
#  W=Withdrawal
#  B==Balance Check
#  T==Transfer amount
#  UM==update mobile
#  UG==update gmail
#  AB==add beneficiary
#  C==apply credit card
#  E==Exit
# UM
# **To proceed further, we need to verify your details first**
# enter your name: Laukik
# enter your mobile no:4561237890
# ***Details matched. do the next step***
# enter the new number: 919192929393
# ***Mobile number is updated into your account successfully***

# %%
{"Laukik":{"name":"Laukik",
                        "pin":4751,
                        "balance":20000,
                        "mobile_no":4561237890,
                        "gmail":"laukik@gmail.com",
                        "credit_card":"no"

# %%
user_data["Laukik"]
# Out:
# {'name': 'Laukik',
#  'pin': 4751,
#  'balance': 20000,
#  'mobile_no': 4561237890,
#  'gmail': 'laukik@gmail.com',
#  'credit_card': 'no'}

# %%
-- pin check and then alllow
-- change pin, first verify the name and number and update the pin
-- Balance check
-- transfer amount to another account
-- update mobile number and gmail
-- add benficiary name
-- apply for new credit card

# %%
user_data
# Out:
# {'Laukik': {'name': 'Laukik',
#   'pin': 4751,
#   'balance': 20000,
#   'mobile_no': 4561237890,
#   'gmail': 'laukik@gmail.com',
#   'credit_card': 'no'},
#  'Ravindra': {'name': 'Ravindra',
#   'pin': 4524,
#   'balance': 45000,
#   'mobile_no': 4815263719,
#   'gmail': 'ravindra@gmail.com',
#   'credit_card': 'no'},
#  'Chetana': {'name': 'Chetana',
#   'pin': 1548,
#   'balance': 40000,
#   'mobile_no': 7531598526,
#   'gmail': 'chetana@gmail.com',
#   'credit_card': 'yes'},
#  'Suraj': {'name': 'Suraj',
#   'pin': 8754,
#   'balance': 80000,
#   'mobile_no': 1478523690,
#   'gmail': 'suraj@gmail.com',
#   'credit_card': 'yes'},
#  'Sarthak': {'name': 'Sarthak',
#   'pin': 9634,
#   'balance': 40000,
#   'mobile_no': 1823965404,
#   'gmail': 'sarthak@gmail.com',
#   'credit_card': 'no'},
#  'Shubham': {'name': 'Shubham',
#   'pin': 4751,
#   'balance': 60000,
#   'mobile_no': 1830257964,
#   'gmail': 'shubham@gmail.com',
#   'credit_card': 'no'}}

# %%
len(str(9665))
# Out:
# 4

# %%
user_data={"Laukik":{"name":"Laukik",
                        "pin":4751,
                        "balance":20000,
                        "mobile_no":4561237890,
                        "gmail":"laukik@gmail.com",
                        "credit_card":"no"
    
                        },
               "Ravindra":{"name":"Ravindra",
                        "pin":4524,
                        "balance":45000,
                        "mobile_no":4815263719,
                        "gmail":"ravindra@gmail.com",
                        "credit_card":"no"
    
                        },
               "Chetana":{"name":"Chetana",
                        "pin":1548,
                        "balance":40000,
                        "mobile_no":7531598526,
                        "gmail":"chetana@gmail.com",
                        "credit_card":"yes"
    
                        },
                 "Suraj":{"name":"Suraj",
                        "pin":8754,
                        "balance":80000,
                        "mobile_no":1478523690,
                        "gmail":"suraj@gmail.com",
                        "credit_card":"yes"
    
                        },
            "Sarthak":{"name":"Sarthak",
                        "pin":9634,
                        "balance":40000,
                        "mobile_no":1823965404,
                        "gmail":"sarthak@gmail.com",
                        "credit_card":"no"
                      },
           "Shubham":{"name":"Shubham",
                        "pin":4751,
                        "balance":60000,
                        "mobile_no":1830257964,
                        "gmail":"shubham@gmail.com",
                        "credit_card":"no"
                     }
}


def update_mobile(name,mobile_no):
        if  mobile_no==user_data[name]["mobile_no"]:
            # user_data.update({"mobile_no":mobile_no})
            print("***Mobile number is updated into your account successfully***")
                    
        else:
            print("Invalid details")
name1=input("enter name: ")
mobile1=int(input("enter number phone: "))
update_mobile(name,mobile)
# Out:
# enter name: Laukik
# enter number phone: 4561237890
# ***Mobile number is updated into your account successfully***

# %%
# name==user_data[name]:

# %%
user_data={"Laukik":{"name1":"Laukik",
                        "pin":4751,
                        "balance":20000,
                        "mobile_no":4561237890,
                        "gmail":"laukik@gmail.com",
                        "credit_card":"no"
    
                        },
               "Ravindra":{"name2":"Ravindra",
                        "pin":4524,
                        "balance":45000,
                        "mobile_no":4815263719,
                        "gmail":"ravindra@gmail.com",
                        "credit_card":"no"
    
                        },
               "Chetana":{"name3":"Chetana",
                        "pin":1548,
                        "balance":40000,
                        "mobile_no":7531598526,
                        "gmail":"chetana@gmail.com",
                        "credit_card":"yes"
    
                        },
                 "Suraj":{"name4":"Suraj",
                        "pin":8754,
                        "balance":80000,
                        "mobile_no":1478523690,
                        "gmail":"suraj@gmail.com",
                        "credit_card":"yes"
    
                        },
            "Sarthak":{"name5":"Sarthak",
                        "pin":9634,
                        "balance":40000,
                        "mobile_no":1823965404,
                        "gmail":"sarthak@gmail.com",
                        "credit_card":"no"
                      },
           "Shubham":{"name6":"Shubham",
                        "pin":4751,
                        "balance":60000,
                        "mobile_no":1830257964,
                        "gmail":"shubham@gmail.com",
                        "credit_card":"no"
                     }
}

def update_mobile(name,mobile_no):
        if  name==user_data[name][name] and mobile_no==user_data[name]["mobile_no"]:
            # user_data.update({"mobile_no":mobile_no})
            print("***Mobile number is updated into your account successfully***")
                    
        else:
            print("Invalid details")
name1=input("enter name: ")
mobile1=int(input("enter number phone: "))
update_mobile(name,mobile)
# Out:
# enter name: Laukik
# enter number phone: 4561237890
# Invalid details

# %%
user_data={"Laukik":{"name1":"Laukik",
                        "pin":4751,
                        "balance":20000,
                        "mobile_no":4561237890,
                        "gmail":"laukik@gmail.com",
                        "credit_card":"no"
    
                        },
               "Ravindra":{"name2":"Ravindra",
                        "pin":4524,
                        "balance":45000,
                        "mobile_no":4815263719,
                        "gmail":"ravindra@gmail.com",
                        "credit_card":"no"
    
                        },
               "Chetana":{"name3":"Chetana",
                        "pin":1548,
                        "balance":40000,
                        "mobile_no":7531598526,
                        "gmail":"chetana@gmail.com",
                        "credit_card":"yes"
    
                        },
                 "Suraj":{"name4":"Suraj",
                        "pin":8754,
                        "balance":80000,
                        "mobile_no":1478523690,
                        "gmail":"suraj@gmail.com",
                        "credit_card":"yes"
    
                        },
            "Sarthak":{"name5":"Sarthak",
                        "pin":9634,
                        "balance":40000,
                        "mobile_no":1823965404,
                        "gmail":"sarthak@gmail.com",
                        "credit_card":"no"
                      },
           "Shubham":{"name6":"Shubham",
                        "pin":4751,
                        "balance":60000,
                        "mobile_no":1830257964,
                        "gmail":"shubham@gmail.com",
                        "credit_card":"no"
                     }
}
"Laukik"==user_data["Laukik"]["name1"]
# Out:
# True

# %%
user_data["Laukik"]
# Out:
# {'name1': 'Laukik',
#  'pin': 4751,
#  'balance': 20000,
#  'mobile_no': 4561237890,
#  'gmail': 'laukik@gmail.com',
#  'credit_card': 'no'}

# %%
1 2 3 4 5 6 7 8 9
