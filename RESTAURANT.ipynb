# %%
items = {
    'Kaju kari - KK':150,
    'Paneer Tikka masala - PTM':200,
    'dal tadka - DT':100,
    'Roti 5 - R5': 100,
    'Jira rice - JR':120,
}

class Bill:
    def __init__(self,bill_item=[]):
        self.bill_item = bill_item
        self.total = 0
        
        
    def add_item(self):
        while True:
            
            for index,item in enumerate(items.items()):
                print(index,item)
                
            print('Exit Menu - "E"')
            choice = input('enter choice- ')
            
            if choice == 'e' or choice == "E":
                
                break
            else:
                for item in items.items():
                    
                    if(item[0].endswith(choice.upper())):
                        print(f'\nyou selected - {item[0]}\n')
                        
                        self.bill_item.append((item))
                        
                        #self.bill_item.update()

                        
    def print_bill(self):
        
        self.total = 0 
        print('\n\nPlease go throgh your bill - ')
        for item in self.bill_item:
            print(item)
            self.total = self.total + item[1]
            
        print(f'kindly pay the bill of - {self.total}')
        
        payment = self.total
        
        while True:
            
            amount = int(input(f'enter the payment - {payment}'))
            if amount == payment:
                print('***********  THANK FOR DINNING WITH US   ************\n\n\n')
                break
                
            elif amount > payment:
                remain = amount - self.total
                print(f'please collect remaining amount - {remain}')
                print('***********  THANK FOR DINNING WITH US   ************\n\n\n')
                break
            elif amount < payment:
                
                payment = payment - amount
                
    def __del__(self):
        del(self.bill_item)
        del(self.total)
        
        print('bill object is closed')
                
                
        



while True:
    
    print("********         WEL-COME TO RESAURANT         ************\n")
    print('1. Order Items - "O" \n2. Generate bill - "G" ')
    print('3. Exit - "E"')
    choice = input('\nEnter your respone - ')
    
    if choice == 'e' or choice =='E' or choice =="3":
        print('***********  THANK YOU !!! VISIT AGAIN   ************\n\n\n')
        break
        
    elif choice == 'o' or choice =='O' or choice =="1":
        try:
            new_bill = Bill()
            #bill_list.append(new_bill)
            new_bill.add_item()
        except:
            print('something is wrong')
            
    elif choice == 'g' or choice =='G'or choice =="2":
        try:
            new_bill.print_bill()            
            new_bill.bill_item.clear()
            
        except:
            print('something is wrong please select correct option !!!')
    else:
        print('enter again')
# Out:
# ********         WEL-COME TO RESAURANT         ************
#
# 1. Order Items - "O"
# 2. Generate bill - "G"
# 3. Exit - "E"
#
# Enter your respone - g
# something is wrong please select correct option !!!
# ********         WEL-COME TO RESAURANT         ************
#
# 1. Order Items - "O"
# 2. Generate bill - "G"
# 3. Exit - "E"
#
# Enter your respone - e
# ***********  THANK YOU !!! VISIT AGAIN   ************
